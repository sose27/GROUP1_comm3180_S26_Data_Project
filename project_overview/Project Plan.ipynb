# %% [markdown]
# ### Project Plan

# %% [markdown]
# #### Steps (milestone 1)

# %% [markdown]
# 1. Refine research question and specify dependent and independent variables
# 2. Find data sources that document demographics (race, age), socioeconomics (educational attainment, income, unemployment rate, employment by industry), and issue voting at the county level in California
# 3. Upload data sources to folder and explain what each will be used for
# 4. Clean each data set, clearly explaining each step involved

# %% [markdown]
# #### Responsibility Breakdown

# %% [markdown]
# -Steps 1 and 2 will be handled collectively by the group
#
# -Each group member will be responsible for explaining and cleaning one data set
#
#     -ACS (DP02, DP03, DP05) -
#
#     -MIT Presidential Election Data -
#
#     -California Statement of Vote -
